# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
x = [1 , 2, 3 , 4]
y = [2 , 4 , 8 , 12]
plt.scatter(x ,y)

# %%
plt.plot(x , y)

# %%
plt.title("Graph")
plt.plot(x , y)
plt.show()

# %%
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x , y)
plt.show()

# %%
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x , y , label = 'y = 2x' , color ='black')
plt.legend()
plt.show()

# %%
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x , y , label = 'y = 2x' , color ='red' , linewidth = 2)
plt.legend()
plt.show()

# %%
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x , y , label = 'y = 2x' , color ='red' , linewidth = 2 , marker = '*' , linestyle = '--')
plt.legend()
plt.show()

# %%
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x , y ,'b*--' , label = 'y = 2x')
plt.legend()
plt.show()

# %%
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x , y ,'go:' , label = 'y = 2x')
plt.legend()
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend()
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , [i*i for i in x2] ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend()
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend(loc = 'lower left')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend(loc = 'upper center')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(1 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend(loc = 10)
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend(loc = 7)
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.xticks(np.arange(0 , 7 , .5))
plt.yticks(np.arange(0 , 13 ))
plt.legend(loc = 'upper center')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.xticks([0 , 1 , 2 , 2.5 , 3 , 4 ,5 , 6])
plt.yticks([i for i in range(0 , 7)] + [9])
plt.legend(loc = 'upper center')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.xticks([0 , 1 , 2 , 2.5 , 3 , 4 ,5 , 6])
plt.yticks(list(range(0 , 15 , 2)))
plt.savefig('plot1.png')
plt.legend(loc = 'upper right')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.xticks([0 , 1 , 2 , 2.5 , 3 , 4 ,5 , 6])
plt.yticks(list(range(0 , 15 , 2)))
plt.savefig('plot2.jpg')
plt.legend(loc = 'upper right')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.xticks([0 , 1 , 2 , 2.5 , 3 , 4 ,5 , 6])
plt.yticks(list(range(0 , 15 , 2)))
plt.savefig('plot3.pdf')
plt.legend(loc = 'upper right')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.xticks([0 , 1 , 2 , 2.5 , 3 , 4 ,5 , 6])
plt.yticks(list(range(0 , 15 , 2)))
plt.savefig('plot4.svg')
plt.legend(loc = 'upper right')
plt.show()

# %%
x = [0 , 1 , 2 , 4 ,5 ,6]
y = [0 , 2 , 4 , 8 , 10 , 12]
x2 = np.arange(0 , 4.5 , .5)
plt.plot(x , y ,'b*--' , label = 'equation1')
plt.plot(x2 , x2**2 ,'g>--' , label = 'equation2' )
plt.title("graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.xticks([0 , 1 , 2 , 2.5 , 3 , 4 ,5 , 6])
plt.yticks(list(range(0 , 15 , 2)))
plt.savefig('plot5.svg' , dpi =500)
plt.legend(loc = 'upper right')
plt.show()

# %%
# change fig size
plt.rcParams['figure.figsize'] = (12 , 9)

# %%
x = [1 , 2 ,3 , 4 , 5]
y = [1 ,4 ,9 , 16 , 25]
plt.title(r'$u= x^2$')
plt.plot(x , y)
plt.show()

# %%
x = [1 , 2 ,3 , 4 , 5]
y = [1 ,4 ,9 , 16 , 25]
plt.title(r'$u= x^2$')
plt.plot(x , y)
plt.legend(bbox_to_anchor= (1.05 , 1))
plt.show()
# Out:
# C:\Users\elmnshawy\AppData\Local\Temp\ipykernel_12012\2512288732.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor= (1.05 , 1))

# %%
x = [1 , 2 ,3 , 4 , 5]
y = [1 ,4 ,9 , 16 , 25]
plt.title(r'$u= x^2$')
plt.plot(x , y)
plt.legend()
plt.show()
# Out:
# C:\Users\elmnshawy\AppData\Local\Temp\ipykernel_12012\2359390663.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.rcParams['figure.figsize'] = (8 , 6)

# %% [markdown]
# # Bar Chart

# %%
labels = ['A' , 'B' , 'C']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values )
plt.yticks(np.arange(0 , 5))
plt.show()

# %%
labels = ['A' , 'B' , 'C']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values )
plt.yticks(np.arange(0 , 8))
plt.show()

# %%
labels = ['A' , 'B' , 'C']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values  , align='edge')
plt.yticks(np.arange(0 , 5))
plt.show()

# %%
labels = ['Ahmed' , 'Basma' , 'Camela']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values  )
plt.xticks(rotation = 45)
plt.yticks(np.arange(0 , 5))
plt.show()

# %%
labels = ['Ahmed' , 'Basma' , 'Camela']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values  )
plt.xticks(rotation = 90)
plt.yticks(np.arange(0 , 5))
plt.show()

# %%
labels = ['Ahmed' , 'Basma' , 'Camela']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values  )
plt.xticks(rotation = 30)
plt.yticks(np.arange(0 , 5))
plt.show()

# %%
labels = ['Ahmed' , 'Basma' , 'Camela']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values  ,width=.3)
plt.yticks(np.arange(0 , 5))
plt.show()

# %%
names = ['ahmed' , 'mohamed' , 'mustafa' , 'tamer' , 'kareem']
values = [2400 , 2100 , 3500 , 6722 , 1212345567]
plt.figure(figsize=(6, 4))
plt.bar(names , values , width=.4)
plt.show()

# %%
labels = ['Ahmed' , 'Basma' , 'Camela']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
bars = plt.bar(labels , values  ,width=.3)
bars[0].set_hatch('/')
bars[1].set_hatch('o')
bars[2].set_hatch('*')
plt.show()

# %%
labels = ['Ahmed' , 'Basma' , 'Camela']
values = [1 , 4 ,2] 
plt.figure(figsize=(6,4))
plt.bar(labels , values  ,width=.3)[1].set_hatch('/')
plt.show()

# %%
x = [1 , 2, 4, 5 , 6]
y = [1 , 4, 8, 10 , 12] 
x2 = np.arange(0 , 4  ,.5)
plt.plot(x , y , 'r*--' , label = '2x')
plt.plot(x2 , x2**2 , 'b*--' )
plt.title('graph')
plt.grid(True)
plt.xlabel("x axis")
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
def addlabels(x , y) : 
    for i in range(len(x)) : 
        plt.text(i , y[i] , y[i] ,ha = 'center')

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27] 

plt.bar(company , revenue)
addlabels(company ,revenue)
plt.show()

# %%
plt.figure(figsize=(8,6))
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # numpyarray : 0 , 1 , 2, 3

plt.bar(company,revenue, width=0.4, label="Revenue") 
plt.bar(xpos-0.4,profit, width=0.4,label="Profit")
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # numpyarray : 0 , 1 , 2, 3

plt.bar(company,revenue, width=0.6, label="Revenue") 
plt.bar(xpos-0.4,profit, width=0.3,label="Profit")
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %% [markdown]
# # Pie chart

# %%
exp_values =[1400 , 600 , 300 ,300 , 250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_values , labels=exp_labels)
plt.show()

# %%
exp_values =[1400 , 600 , 300 ,300 , 250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_values , labels=exp_labels , radius=2)
plt.show()

# %%
exp_values =[1400 , 600 , 300 ,300 , 250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_values , labels=exp_labels , radius=2 , autopct='%0.0f%%') 
plt.show()

# %%
exp_values =[1400 , 600 , 300 ,300 , 250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_values , labels=exp_labels , radius=2 , autopct='%0.4f%%') 
plt.show()

# %%
exp_values =[1400 , 600 , 300 ,300 , 250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_values , labels=exp_labels , radius=1.5 , autopct='%0.2f%%' , explode=[0,0 ,.1,0,0]) 
plt.show()
